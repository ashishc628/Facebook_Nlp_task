# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
pip install xlwt
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
dataFrame = pd.read_excel('Question Set - FB_Page_Decoder_Data_Analyst (1).xlsx')
dataFrame.head()
# Out:
#    Unnamed: 0                                         Unnamed: 1
# 0         NaN      Please Note  - You may have to clean the data
# 1         NaN                                                NaN
# 2         1.0  Which User is interacting with the page the hi...
# 3         2.0  In Post_List, you have a column called Post_Te...
# 4         3.0  In Comments, you have a column called comment ...

# %%
dataFrame_post_list = pd.read_excel('Question Set - FB_Page_Decoder_Data_Analyst (1).xlsx',sheet_name='Post_List')

# %%
dataFrame_post_list.head()
# Out:
#    post_date                                          Post_Text  \
# 0 2020-07-22  Dear Shankra Family, \n first of all, we want ...
# 1 2020-10-30  Walking towards the future with the strongest ...
# 2 2020-10-27  The Mesolcina Mountain Chain, home to Shankra ...
# 3 2020-10-24  We believe in pure music, freely expressed by ...
# 4 2020-10-21  The beating heart of our Valley, Shankra Stage...
#
#                   Post_Embedded_URL  \
# 0  http://bit.ly/ShankraTickets2021
# 1         b.link/ShankraTickets2021
# 2         b.link/ShankraTickets2021
# 3         b.link/ShankraTickets2021
# 4         b.link/ShankraTickets2021
#
#                                             Post_URL
# 0  https://m.facebook.com/story.php?story_fbid=30...
# 1  https://m.facebook.com/story.php?story_fbid=33...
# 2  https://m.facebook.com/story.php?story_fbid=33...
# 3  https://m.facebook.com/story.php?story_fbid=33...
# 4  https://m.facebook.com/story.php?story_fbid=33...

# %%
dataFrame_Post_List.head()
# Out:
#    post_date                                          Post_Text  \
# 0 2020-07-22  Dear Shankra Family, \n first of all, we want ...
# 1 2020-10-30  Walking towards the future with the strongest ...
# 2 2020-10-27  The Mesolcina Mountain Chain, home to Shankra ...
# 3 2020-10-24  We believe in pure music, freely expressed by ...
# 4 2020-10-21  The beating heart of our Valley, Shankra Stage...
#
#                   Post_Embedded_URL  \
# 0  http://bit.ly/ShankraTickets2021
# 1         b.link/ShankraTickets2021
# 2         b.link/ShankraTickets2021
# 3         b.link/ShankraTickets2021
# 4         b.link/ShankraTickets2021
#
#                                             Post_URL
# 0  https://m.facebook.com/story.php?story_fbid=30...
# 1  https://m.facebook.com/story.php?story_fbid=33...
# 2  https://m.facebook.com/story.php?story_fbid=33...
# 3  https://m.facebook.com/story.php?story_fbid=33...
# 4  https://m.facebook.com/story.php?story_fbid=33...

# %%
dataFrame_Comments = pd.read_excel('Question Set - FB_Page_Decoder_Data_Analyst (1).xlsx',sheet_name='Comments')

# %%
dataFrame_Comments.head()
# Out:
#                        Name                               People_URL  \
# 0          Andreas Kenotaph   https://m.facebook.com/andreas.inkmann
# 1   Top fan\nLuca Maccarone  https://m.facebook.com/luca.maccarone.7
# 2                 Lia Silva    https://m.facebook.com/alma.lilly.aho
# 3  Author\nShankra Festival  https://m.facebook.com/shankrafestival/
# 4  Author\nShankra Festival  https://m.facebook.com/shankrafestival/
#
#   Page_Or_Person                                           Post_URL  \
# 0         Person  https://m.facebook.com/story.php?story_fbid=30...
# 1         Person  https://m.facebook.com/story.php?story_fbid=30...
# 2         Person  https://m.facebook.com/story.php?story_fbid=30...
# 3           Page  https://m.facebook.com/story.php?story_fbid=30...
# 4           Page  https://m.facebook.com/story.php?story_fbid=30...
#
#                                              Comment
# 0  Felt good to give you something back for all t...
# ...

# %%
dataFrame_Reactions = pd.read_excel('Question Set - FB_Page_Decoder_Data_Analyst (1).xlsx',sheet_name='Shares')

# %%
dataFrame_Reactions
# Out:
#                       Shares_By  \
# 0                  Eric Keriguy
# 1    Psytranceworldwidemagazine
# 2                    Dj Kalanio
# 3                    Silvia Sey
# 4            Giovanni Ricciardi
# ..                          ...
# 236                    Pao Garo
# 237                  Lella Toma
# 238             Kim Pixii Lopes
# 239               Dennis Boarin
# 240     Brittany Brittou Bohaer
#
#                                          Shares_By_URL Page_Or_Person  \
# 0                https://m.facebook.com/eric.keriguy.7         Person
# 1    https://m.facebook.com/psytranceworldwidemagaz...           Page
# 2                    https://m.facebook.com/kalanio44/           Page
# 3            https://m.facebook.com/silvia.mandelli.73         Person
# 4       https://m.facebook.com/giovanniricciardijunior         Person
# ..                                                 ...            ...
# 236                 https://m.facebook.com/pao.garoush         Person
# ...

# %%
dataFrame_Shares = pd.read_excel('Question Set - FB_Page_Decoder_Data_Analyst (1).xlsx',sheet_name='Shares')

# %%
dataFrame_Shares.head()
# Out:
#                     Shares_By  \
# 0                Eric Keriguy
# 1  Psytranceworldwidemagazine
# 2                  Dj Kalanio
# 3                  Silvia Sey
# 4          Giovanni Ricciardi
#
#                                        Shares_By_URL Page_Or_Person  \
# 0              https://m.facebook.com/eric.keriguy.7         Person
# 1  https://m.facebook.com/psytranceworldwidemagaz...           Page
# 2                  https://m.facebook.com/kalanio44/           Page
# 3          https://m.facebook.com/silvia.mandelli.73         Person
# 4     https://m.facebook.com/giovanniricciardijunior         Person
#
#   Total_Share                                           Post_URL
# 0   56 shares  https://m.facebook.com/story.php?story_fbid=30...
# 1   56 shares  https://m.facebook.com/story.php?story_fbid=30...
# 2   56 shares  https://m.facebook.com/story.php?story_fbid=30...
# 3   56 shares  https://m.facebook.com/story.php?story_fbid=30...
# ...

# %%
# Now for cobine dataframes....in stack form


# pandas provides function Concatenate or "Stack" a list of pd.dataFrames


# syntax : pd.concat([amex , nasdaq , nyse ] )

# %%
dataFrame = pd.concat([dataFrame_Post_List,dataFrame_Comments,dataFrame_Reactions,dataFrame_Shares])

# %%
dataFrame.head(100)
# Out:
#     post_date                                          Post_Text  \
# 0  2020-07-22  Dear Shankra Family, \n first of all, we want ...
# 1  2020-10-30  Walking towards the future with the strongest ...
# 2  2020-10-27  The Mesolcina Mountain Chain, home to Shankra ...
# 3  2020-10-24  We believe in pure music, freely expressed by ...
# 4  2020-10-21  The beating heart of our Valley, Shankra Stage...
# ..        ...                                                ...
# 67        NaT                                                NaN
# 68        NaT                                                NaN
# 69        NaT                                                NaN
# 70        NaT                                                NaN
# 71        NaT                                                NaN
#
#                    Post_Embedded_URL  \
# 0   http://bit.ly/ShankraTickets2021
# 1          b.link/ShankraTickets2021
# 2          b.link/ShankraTickets2021
# ...

# %%
dataFrame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1251 entries, 0 to 240
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   post_date          28 non-null     datetime64[ns]
#  1   Post_Text          28 non-null     object
#  2   Post_Embedded_URL  21 non-null     object
#  3   Post_URL           1251 non-null   object
#  4   Name               741 non-null    object
#  5   People_URL         741 non-null    object
#  6   Page_Or_Person     1223 non-null   object
#  7   Comment            732 non-null    object
#  8   Shares_By          482 non-null    object
#  9   Shares_By_URL      482 non-null    object
#  10  Total_Share        482 non-null    object
# dtypes: datetime64[ns](1), object(10)
# memory usage: 117.3+ KB

# %%
dataFrame.shapee
# Out:
# (1251, 11)

# %%
dataFrame.isna().sum()
# Out:
# post_date            1223
# Post_Text            1223
# Post_Embedded_URL    1230
# Post_URL                0
# Name                  510
# People_URL            510
# Page_Or_Person         28
# Comment               519
# Shares_By             769
# Shares_By_URL         769
# Total_Share           769
# dtype: int64

# %%
print(dataFrame['Page_Or_Person']).head(10)
# Out:
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
#         ...
# 236    Person
# 237    Person
# 238    Person
# 239    Person
# 240    Person
# Name: Page_Or_Person, Length: 1251, dtype: object
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-40-ba44a914e344> in <module>
# ----> 1 print(dataFrame['Page_Or_Person']).head(10)
#
# AttributeError: 'NoneType' object has no attribute 'head'

# %%
missing_value_formats = ["NAN","?","NA","n/a", "na", "--"]
# dataFrame = pd.read("employees.csv", na_values = missing_value_formats)

def make_int(i):
    try:
        return int(i)
    except:
        return pd.np.nan

# apply make_int function to the entire series using map
df['Name'] = df['Name'].map(make_int)
print(dataFrame['Name'].head())

# %%
dataFrame.head()
# Out:
#    post_date                                          Post_Text  \
# 0 2020-07-22  Dear Shankra Family, \n first of all, we want ...
# 1 2020-10-30  Walking towards the future with the strongest ...
# 2 2020-10-27  The Mesolcina Mountain Chain, home to Shankra ...
# 3 2020-10-24  We believe in pure music, freely expressed by ...
# 4 2020-10-21  The beating heart of our Valley, Shankra Stage...
#
#                   Post_Embedded_URL  \
# 0  http://bit.ly/ShankraTickets2021
# 1         b.link/ShankraTickets2021
# 2         b.link/ShankraTickets2021
# 3         b.link/ShankraTickets2021
# 4         b.link/ShankraTickets2021
#
#                                             Post_URL Name People_URL  \
# 0  https://m.facebook.com/story.php?story_fbid=30...  NaN        NaN
# 1  https://m.facebook.com/story.php?story_fbid=33...  NaN        NaN
# 2  https://m.facebook.com/story.php?story_fbid=33...  NaN        NaN
# 3  https://m.facebook.com/story.php?story_fbid=33...  NaN        NaN
# ...

# %%
dataFrame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1251 entries, 0 to 240
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   post_date          28 non-null     datetime64[ns]
#  1   Post_Text          28 non-null     object
#  2   Post_Embedded_URL  21 non-null     object
#  3   Post_URL           1251 non-null   object
#  4   Name               741 non-null    object
#  5   People_URL         741 non-null    object
#  6   Page_Or_Person     1223 non-null   object
#  7   Comment            732 non-null    object
#  8   Shares_By          482 non-null    object
#  9   Shares_By_URL      482 non-null    object
#  10  Total_Share        482 non-null    object
# dtypes: datetime64[ns](1), object(10)
# memory usage: 117.3+ KB

# %%
# NaN values are marked True
print(dataFrame['Name'].isnull().head(10))
# NaN values are marked False 
print(dataFrame['Name'].notnull().head(10))
# Out:
# 0    True
# 1    True
# 2    True
# 3    True
# 4    True
# 5    True
# 6    True
# 7    True
# 8    True
# 9    True
# Name: Name, dtype: bool
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6    False
# 7    False
# 8    False
# 9    False
# Name: Name, dtype: bool

# %%
# notnull will return False for all NaN values
null_filter = dataFrame['Name'].notnull()
# prints only those rows where null_filter is True
print(dataFrame[null_filter])
# Out:
#     post_date Post_Text Post_Embedded_URL  \
# 0         NaT       NaN               NaN
# 1         NaT       NaN               NaN
# 2         NaT       NaN               NaN
# 3         NaT       NaN               NaN
# 4         NaT       NaN               NaN
# ..        ...       ...               ...
# 736       NaT       NaN               NaN
# 737       NaT       NaN               NaN
# 738       NaT       NaN               NaN
# 739       NaT       NaN               NaN
# 740       NaT       NaN               NaN
#
#                                               Post_URL  \
# 0    https://m.facebook.com/story.php?story_fbid=30...
# 1    https://m.facebook.com/story.php?story_fbid=30...
# 2    https://m.facebook.com/story.php?story_fbid=30...
# 3    https://m.facebook.com/story.php?story_fbid=30...
# 4    https://m.facebook.com/story.php?story_fbid=30...
# ..                                                 ...
# 736  https://m.facebook.com/story.php?story_fbid=24...
# ...

# %%
print(dataFrame.isnull().values.any())
# Out:
# True

# %%
print(dataFrame.isnull().sum())
# Out:
# post_date            1223
# Post_Text            1223
# Post_Embedded_URL    1230
# Post_URL                0
# Name                  510
# People_URL            510
# Page_Or_Person         28
# Comment               519
# Shares_By             769
# Shares_By_URL         769
# Total_Share           769
# dtype: int64

# %%
#1. Function to replace NAN values with mode value
def impute_nan_most_frequent_category(DataFrame,ColName):
    # .mode()[0] - gives first category name
     most_frequent_category=DataFrame[ColName].mode()[0]
    
    # replace nan values with most occured category
     DataFrame[ColName + "_Imputed"] = DataFrame[ColName]
     DataFrame[ColName + "_Imputed"].fillna(most_frequent_category,inplace=True)
#2. Call function to impute most occured category
for Columns in ['post_date','Post_Text','Post_Embedded_URL','Name','People_URL','Page_Or_Person','Comment','Shares_By','Shares_By_URL','Total_Share']:
    impute_nan_most_frequent_category(dataFrame,Columns)
    
# Display imputed result
dataFrame[['post_date','Post_Text','Post_Embedded_URL','Name','People_URL','Page_Or_Person','Comment','Shares_By','Shares_By_URL','Total_Share']].head(10)
#3. Drop actual columns
dataFrame = dataFrame.drop(['post_date','Post_Text','Post_Embedded_URL','Name','People_URL','Page_Or_Person','Comment','Shares_By','Shares_By_URL','Total_Share'], axis = 1)

# %%
dataFrame.head()
# Out:
#                                             Post_URL post_date_Imputed  \
# 0  https://m.facebook.com/story.php?story_fbid=30...        2020-07-22
# 1  https://m.facebook.com/story.php?story_fbid=33...        2020-10-30
# 2  https://m.facebook.com/story.php?story_fbid=33...        2020-10-27
# 3  https://m.facebook.com/story.php?story_fbid=33...        2020-10-24
# 4  https://m.facebook.com/story.php?story_fbid=33...        2020-10-21
#
#                                    Post_Text_Imputed  \
# 0  Dear Shankra Family, \n first of all, we want ...
# 1  Walking towards the future with the strongest ...
# 2  The Mesolcina Mountain Chain, home to Shankra ...
# 3  We believe in pure music, freely expressed by ...
# 4  The beating heart of our Valley, Shankra Stage...
#
#           Post_Embedded_URL_Imputed              Name_Imputed  \
# 0  http://bit.ly/ShankraTickets2021  Author\nShankra Festival
# 1         b.link/ShankraTickets2021  Author\nShankra Festival
# ...

# %%
print(dataFrame.isnull().sum())
# Out:
# Post_URL                     0
# post_date_Imputed            0
# Post_Text_Imputed            0
# Post_Embedded_URL_Imputed    0
# Name_Imputed                 0
# People_URL_Imputed           0
# Page_Or_Person_Imputed       0
# Comment_Imputed              0
# Shares_By_Imputed            0
# Shares_By_URL_Imputed        0
# Total_Share_Imputed          0
# dtype: int64
